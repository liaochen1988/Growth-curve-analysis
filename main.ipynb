# %%
import string
from croissance_wrapper import growth_curve_analysis_chenL

# %% [markdown]
# # 010720GlycerolGrowthCurve_Hildi

# %%
column_strains_0107_Hildi = ['Blank','F22031','F30658','F34365','F63912','F9670','M1608','H27930','H47921','H5708','UCBPP-PA14','Water']
well_name_dict_0107_Hildi = {}
for row in string.ascii_uppercase[:8]:
    for col in range(1,13):
        well_name_dict_0107_Hildi[row+str(col)] = column_strains_0107_Hildi[col-1]
well_name_dict_0107_Hildi
# Out:
# {'A1': 'Blank',
#  'A2': 'F22031',
#  'A3': 'F30658',
#  'A4': 'F34365',
#  'A5': 'F63912',
#  'A6': 'F9670',
#  'A7': 'M1608',
#  'A8': 'H27930',
#  'A9': 'H47921',
#  'A10': 'H5708',
#  'A11': 'UCBPP-PA14',
#  'A12': 'Water',
#  'B1': 'Blank',
#  'B2': 'F22031',
#  'B3': 'F30658',
#  'B4': 'F34365',
#  'B5': 'F63912',
#  'B6': 'F9670',
#  'B7': 'M1608',
#  'B8': 'H27930',
#  'B9': 'H47921',
#  'B10': 'H5708',
#  'B11': 'UCBPP-PA14',
#  'B12': 'Water',
#  'C1': 'Blank',
#  'C2': 'F22031',
#  'C3': 'F30658',
#  'C4': 'F34365',
#  'C5': 'F63912',
#  'C6': 'F9670',
#  'C7': 'M1608',
#  'C8': 'H27930',
#  'C9': 'H47921',
#  'C10': 'H5708',
#  'C11': 'UCBPP-PA14',
#  'C12': 'Water',
#  'D1': 'Blank',
#  'D2': 'F22031',
#  'D3': 'F30658',
#  'D4': 'F34365',
#  'D5': 'F63912',
#  'D6': 'F9670',
#  'D7': 'M1608',
#  'D8': 'H27930',
#  'D9': 'H47921',
#  'D10': 'H5708',
#  'D11': 'UCBPP-PA14',
#  'D12': 'Water',
#  'E1': 'Blank',
#  'E2': 'F22031',
#  'E3': 'F30658',
#  'E4': 'F34365',
# ...

# %%
# %run croissance_wrapper.py
df2write_010720GlycerolGrowthCurve_Hildi = growth_curve_analysis_chenL(
    'data/010720GlycerolGrowthCurve_Hildi.xlsx',
    blank=['12'],
    which_curves=['C9'],
    OD_cutoff=0.0,
    verbose=1,
    is_plot=True,
    plot_dim=[1,1],
    # xlim=[18,30],
    # ylim=[0.0,1],
    fitting_method_in_plot='EXP',
    is_write=True,
    well_name_dict=well_name_dict_0107_Hildi
)
# Out:
# A1  skipped.
# B1  skipped.
# C1  skipped.
# D1  skipped.
# E1  skipped.
# F1  skipped.
# G1  skipped.
# H1  skipped.
# A2  skipped.
# B2  skipped.
# C2  skipped.
# D2  skipped.
# E2  skipped.
# F2  skipped.
# G2  skipped.
# H2  skipped.
# A3  skipped.
# B3  skipped.
# C3  skipped.
# D3  skipped.
# E3  skipped.
# F3  skipped.
# G3  skipped.
# H3  skipped.
# A4  skipped.
# B4  skipped.
# C4  skipped.
# D4  skipped.
# E4  skipped.
# F4  skipped.
# G4  skipped.
# H4  skipped.
# A5  skipped.
# B5  skipped.
# C5  skipped.
# D5  skipped.
# E5  skipped.
# F5  skipped.
# G5  skipped.
# H5  skipped.
# A6  skipped.
# B6  skipped.
# C6  skipped.
# D6  skipped.
# E6  skipped.
# F6  skipped.
# G6  skipped.
# H6  skipped.
# A7  skipped.
# B7  skipped.
# C7  skipped.
# D7  skipped.
# E7  skipped.
# F7  skipped.
# G7  skipped.
# H7  skipped.
# A8  skipped.
# B8  skipped.
# C8  skipped.
# D8  skipped.
# E8  skipped.
# F8  skipped.
# G8  skipped.
# H8  skipped.
# A9  skipped.
# B9  skipped.
# ...

# %%
df2write_010720GlycerolGrowthCurve_Hildi.head()
# Out:
#    id    name  phase subphase  start_time   end_time  start_OD  end_OD  \
# 0  B3  F30658      1        A    2.032278  21.846917    0.0036  0.4727
# 1  B3  F30658      2        A   22.016278  27.774389    0.5281  0.8926
# 2  B3  F30658      3        A   27.943750  33.363139    0.9084  0.8970
# 3  B3  F30658      3        B   34.379278  46.403528    0.8821  0.3376
#
#        area  growth_rate_EXP    R2_EXP  growth_rate_EXP_wOS  R2_EXP_wOS  \
# 0  1.004022         0.534165  0.910964             0.733148    0.949027
# 1  4.817312         0.048597  0.488408             0.048596    0.488408
# 2  4.936572        -0.005933  0.413695            -0.099422    0.417190
# 3  7.429318        -0.078309  0.970528            -0.078309    0.970528
#
#    growth_rate_ZG     R2_ZG  growth_rate_ZL     R2_ZL
# 0        0.763628  0.927151    6.796879e-01  0.945904
# 1        0.052776  0.500543    5.021306e-02  0.493269
# 2       -0.000000  0.659680   -3.695404e-21  0.657982
# ...

# %% [markdown]
# # 010720GlycerolGrowthCurve_Maurice

# %%
column_strains_0107_Maurice = ['Blank','T38079','UCBPP-PA14','Water','Empty','Empty','Empty','Empty','Empty','Empty','Empty','Empty']
well_name_dict_0107_Maurice = {}
for row in string.ascii_uppercase[:8]:
    for col in range(1,13):
        well_name_dict_0107_Maurice[row+str(col)] = column_strains_0107_Maurice[col-1]
well_name_dict_0107_Maurice
# Out:
# {'A1': 'Blank',
#  'A2': 'T38079',
#  'A3': 'UCBPP-PA14',
#  'A4': 'Water',
#  'A5': 'Empty',
#  'A6': 'Empty',
#  'A7': 'Empty',
#  'A8': 'Empty',
#  'A9': 'Empty',
#  'A10': 'Empty',
#  'A11': 'Empty',
#  'A12': 'Empty',
#  'B1': 'Blank',
#  'B2': 'T38079',
#  'B3': 'UCBPP-PA14',
#  'B4': 'Water',
#  'B5': 'Empty',
#  'B6': 'Empty',
#  'B7': 'Empty',
#  'B8': 'Empty',
#  'B9': 'Empty',
#  'B10': 'Empty',
#  'B11': 'Empty',
#  'B12': 'Empty',
#  'C1': 'Blank',
#  'C2': 'T38079',
#  'C3': 'UCBPP-PA14',
#  'C4': 'Water',
#  'C5': 'Empty',
#  'C6': 'Empty',
#  'C7': 'Empty',
#  'C8': 'Empty',
#  'C9': 'Empty',
#  'C10': 'Empty',
#  'C11': 'Empty',
#  'C12': 'Empty',
#  'D1': 'Blank',
#  'D2': 'T38079',
#  'D3': 'UCBPP-PA14',
#  'D4': 'Water',
#  'D5': 'Empty',
#  'D6': 'Empty',
#  'D7': 'Empty',
#  'D8': 'Empty',
#  'D9': 'Empty',
#  'D10': 'Empty',
#  'D11': 'Empty',
#  'D12': 'Empty',
#  'E1': 'Blank',
#  'E2': 'T38079',
#  'E3': 'UCBPP-PA14',
#  'E4': 'Water',
#  'E5': 'Empty',
# ...

# %%
# %run growth_curve_analysis.py

df2write_010720GlycerolGrowthCurve_Maurice = growth_curve_analysis_chenL(
    '../data/010720GlycerolGrowthCurve_Maurice.xlsx',
    blank=['4'],
    #which_curves=['E3','G3'],
    OD_cutoff=0.0,
    verbose=0,
    is_plot=True,
    # plot_dim=[2,1],
    # xlim=[18,30],
    # ylim=[0.0,1],
    fitting_method_in_plot=['exp'],
    is_write=True,
    R2_logscale=False,
    well_name_dict=well_name_dict_0107_Maurice
)
# Out:
# /usr/local/lib/python3.7/site-packages/scipy/optimize/minpack.py:808: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /usr/local/lib/python3.7/site-packages/croissance/estimation/regression.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   return numpy.var(fit) / numpy.var(series.values - fit)
# /usr/local/lib/python3.7/site-packages/croissance/estimation/regression.py:45: RuntimeWarning: divide by zero encountered in double_scalars
#   intercept = - c / slope
# /usr/local/lib/python3.7/site-packages/croissance/estimation/regression.py:62: RuntimeWarning: divide by zero encountered in double_scalars
#   intercept = numpy.log(1 / popt[0]) / slope

# %%
df2write_010720GlycerolGrowthCurve_Maurice.head()
# Out:
#    curve well  phase  start_time   end_time  growth_rate_EXP   std_EXP  \
# 0  Blank   A1    1.0   16.427389  18.290278         1.398762  0.325618
# 1  Blank   B1    NaN         NaN        NaN              NaN       NaN
# 2  Blank   C1    NaN         NaN        NaN              NaN       NaN
# 3  Blank   D1    NaN         NaN        NaN              NaN       NaN
# 4  Blank   E1    NaN         NaN        NaN              NaN       NaN
#
#      R2_EXP  growth_rate_EXP_wOS   std_EXP_wOS  R2_EXP_wOS  growth_rate_ZG  \
# 0  0.765615             1.398761  1.068641e-07    0.765615             0.0
# 1       NaN                  NaN           NaN         NaN             NaN
# 2       NaN                  NaN           NaN         NaN             NaN
# 3       NaN                  NaN           NaN         NaN             NaN
# 4       NaN                  NaN           NaN         NaN             NaN
#
#       R2_ZG  growth_rate_ZL     R2_ZL  growth_ratt_std_exp
# ...

# %% [markdown]
# # 011520GlycerolGrowthCurve_Hildi

# %%
column_strains_0115_Hildi = ['Blank','W70322','X9820','UCBPP-PA14','Water','Empty','Empty','Empty','Empty','Empty','Empty','Empty']
well_name_dict_0115_Hildi = {}
for row in string.ascii_uppercase[:8]:
    for col in range(1,13):
        well_name_dict_0115_Hildi[row+str(col)] = column_strains_0115_Hildi[col-1]
well_name_dict_0115_Hildi
# Out:
# {'A1': 'Blank',
#  'A2': 'W70322',
#  'A3': 'X9820',
#  'A4': 'UCBPP-PA14',
#  'A5': 'Water',
#  'A6': 'Empty',
#  'A7': 'Empty',
#  'A8': 'Empty',
#  'A9': 'Empty',
#  'A10': 'Empty',
#  'A11': 'Empty',
#  'A12': 'Empty',
#  'B1': 'Blank',
#  'B2': 'W70322',
#  'B3': 'X9820',
#  'B4': 'UCBPP-PA14',
#  'B5': 'Water',
#  'B6': 'Empty',
#  'B7': 'Empty',
#  'B8': 'Empty',
#  'B9': 'Empty',
#  'B10': 'Empty',
#  'B11': 'Empty',
#  'B12': 'Empty',
#  'C1': 'Blank',
#  'C2': 'W70322',
#  'C3': 'X9820',
#  'C4': 'UCBPP-PA14',
#  'C5': 'Water',
#  'C6': 'Empty',
#  'C7': 'Empty',
#  'C8': 'Empty',
#  'C9': 'Empty',
#  'C10': 'Empty',
#  'C11': 'Empty',
#  'C12': 'Empty',
#  'D1': 'Blank',
#  'D2': 'W70322',
#  'D3': 'X9820',
#  'D4': 'UCBPP-PA14',
#  'D5': 'Water',
#  'D6': 'Empty',
#  'D7': 'Empty',
#  'D8': 'Empty',
#  'D9': 'Empty',
#  'D10': 'Empty',
#  'D11': 'Empty',
#  'D12': 'Empty',
#  'E1': 'Blank',
#  'E2': 'W70322',
#  'E3': 'X9820',
#  'E4': 'UCBPP-PA14',
#  'E5': 'Water',
# ...

# %%
# %run growth_curve_analysis.py

df2write_011520GlycerolGrowthCurve_Hildi = growth_curve_analysis_chenL(
    '../data/011520GlycerolGrowthCurve_Hildi.xlsx',
    blank=['5'],
    #which_curves=['E3','G3'],
    OD_cutoff=0.0,
    verbose=0,
    is_plot=True,
    # plot_dim=[2,1],
    # xlim=[18,30],
    # ylim=[0.0,1],
    fitting_method_in_plot=['exp'],
    is_write=True,
    R2_logscale=False,
    well_name_dict=well_name_dict_0115_Hildi
)
# Out:
# /usr/local/lib/python3.7/site-packages/croissance/estimation/regression.py:45: RuntimeWarning: divide by zero encountered in double_scalars
#   intercept = - c / slope
# /usr/local/lib/python3.7/site-packages/croissance/estimation/regression.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   return numpy.var(fit) / numpy.var(series.values - fit)
# /usr/local/lib/python3.7/site-packages/scipy/optimize/minpack.py:808: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /usr/local/lib/python3.7/site-packages/croissance/estimation/regression.py:62: RuntimeWarning: divide by zero encountered in double_scalars
#   intercept = numpy.log(1 / popt[0]) / slope

# %%
df2write_011520GlycerolGrowthCurve_Hildi.head()
# Out:
#    curve well  phase  start_time   end_time  growth_rate_EXP  std_EXP  \
# 0  Blank   A1    1.0    4.064556  16.427556         0.107442  0.01252
# 1  Blank   B1    NaN         NaN        NaN              NaN      NaN
# 2  Blank   C1    NaN         NaN        NaN              NaN      NaN
# 3  Blank   D1    NaN         NaN        NaN              NaN      NaN
# 4  Blank   E1    NaN         NaN        NaN              NaN      NaN
#
#     R2_EXP  growth_rate_EXP_wOS  std_EXP_wOS  R2_EXP_wOS  growth_rate_ZG  \
# 0  0.56266             0.107442     0.069783     0.56266        0.190738
# 1      NaN                  NaN          NaN         NaN             NaN
# 2      NaN                  NaN          NaN         NaN             NaN
# 3      NaN                  NaN          NaN         NaN             NaN
# 4      NaN                  NaN          NaN         NaN             NaN
#
#       R2_ZG  growth_rate_ZL     R2_ZL  growth_ratt_std_exp
# ...

# %% [markdown]
# # 011520GlycerolGrowthCurve_Maurice

# %%
column_strains_0115_Maurice = ['Blank','M55212','M6057','M74707','T52373','T6313','T63266','W16407','W25037','W45909','UCBPP-PA14','Water']
well_name_dict_0115_Maurice = {}
for row in string.ascii_uppercase[:8]:
    for col in range(1,13):
        well_name_dict_0115_Maurice[row+str(col)] = column_strains_0115_Maurice[col-1]
well_name_dict_0115_Maurice
# Out:
# {'A1': 'Blank',
#  'A2': 'M55212',
#  'A3': 'M6057',
#  'A4': 'M74707',
#  'A5': 'T52373',
#  'A6': 'T6313',
#  'A7': 'T63266',
#  'A8': 'W16407',
#  'A9': 'W25037',
#  'A10': 'W45909',
#  'A11': 'UCBPP-PA14',
#  'A12': 'Water',
#  'B1': 'Blank',
#  'B2': 'M55212',
#  'B3': 'M6057',
#  'B4': 'M74707',
#  'B5': 'T52373',
#  'B6': 'T6313',
#  'B7': 'T63266',
#  'B8': 'W16407',
#  'B9': 'W25037',
#  'B10': 'W45909',
#  'B11': 'UCBPP-PA14',
#  'B12': 'Water',
#  'C1': 'Blank',
#  'C2': 'M55212',
#  'C3': 'M6057',
#  'C4': 'M74707',
#  'C5': 'T52373',
#  'C6': 'T6313',
#  'C7': 'T63266',
#  'C8': 'W16407',
#  'C9': 'W25037',
#  'C10': 'W45909',
#  'C11': 'UCBPP-PA14',
#  'C12': 'Water',
#  'D1': 'Blank',
#  'D2': 'M55212',
#  'D3': 'M6057',
#  'D4': 'M74707',
#  'D5': 'T52373',
#  'D6': 'T6313',
#  'D7': 'T63266',
#  'D8': 'W16407',
#  'D9': 'W25037',
#  'D10': 'W45909',
#  'D11': 'UCBPP-PA14',
#  'D12': 'Water',
#  'E1': 'Blank',
#  'E2': 'M55212',
#  'E3': 'M6057',
#  'E4': 'M74707',
# ...

# %%
# %run growth_curve_analysis.py

df2write_011520GlycerolGrowthCurve_Maurice = growth_curve_analysis_chenL(
    '../data/011520GlycerolGrowthCurve_Maurice.xlsx',
    blank=['12'],
    #which_curves=['E3','G3'],
    OD_cutoff=0.0,
    verbose=0,
    is_plot=True,
    # plot_dim=[2,1],
    # xlim=[18,30],
    # ylim=[0.0,1],
    fitting_method_in_plot=['exp'],
    is_write=True,
    R2_logscale=False,
    well_name_dict=well_name_dict_0115_Maurice
)
# Out:
# /Users/liaoc/GoogleDrive/Guillem_metabolomics_paper/growth_curve_analysis_fit_w_Croissance_2nd_derive_negative/growth_curve_analysis.py:23: RuntimeWarning: overflow encountered in exp
#   return y0 + A/(1+np.exp(4*mu/A*(lag-x)+2))
# /usr/local/lib/python3.7/site-packages/croissance/estimation/regression.py:45: RuntimeWarning: divide by zero encountered in double_scalars
#   intercept = - c / slope
# /usr/local/lib/python3.7/site-packages/croissance/estimation/regression.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   return numpy.var(fit) / numpy.var(series.values - fit)
# /usr/local/lib/python3.7/site-packages/scipy/optimize/minpack.py:808: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /Users/liaoc/GoogleDrive/Guillem_metabolomics_paper/growth_curve_analysis_fit_w_Croissance_2nd_derive_negative/growth_curve_analysis.py:20: RuntimeWarning: overflow encountered in exp
# ...

# %%
df2write_011520GlycerolGrowthCurve_Maurice.head()
# Out:
#    curve well  phase  start_time   end_time  growth_rate_EXP  \
# 0  Blank   A1    NaN         NaN        NaN              NaN
# 1  Blank   B1    NaN         NaN        NaN              NaN
# 2  Blank   C1    1.0   21.000361  28.960139         0.181299
# 3  Blank   D1    NaN         NaN        NaN              NaN
# 4  Blank   E1    NaN         NaN        NaN              NaN
#
#    growth_ratt_std_exp    R2_EXP  std_EXP_wOS  growth_rate_EXP_wOS  \
# 0                  NaN       NaN          NaN                  NaN
# 1                  NaN       NaN          NaN                  NaN
# 2                  NaN  0.742151     0.088583             0.181299
# 3                  NaN       NaN          NaN                  NaN
# 4                  NaN       NaN          NaN                  NaN
#
#    R2_EXP_wOS  growth_rate_ZG     R2_ZG  growth_rate_ZL     R2_ZL  std_EXP
# 0         NaN             NaN       NaN             NaN       NaN      NaN
# ...

# %% [markdown]
# # 012120GlycerolGrowthCurve_Spark

# %%
column_strains_0121_Spark = ['Blank','F20590','F23197','F30658','F5677','M37351','S86968','T36994','W36662','W60856','UCBPP-PA14','Water']
well_name_dict_0121_Spark = {}
for row in string.ascii_uppercase[:8]:
    for col in range(1,13):
        well_name_dict_0121_Spark[row+str(col)] = column_strains_0121_Spark[col-1]
well_name_dict_0121_Spark
# Out:
# {'A1': 'Blank',
#  'A2': 'F20590',
#  'A3': 'F23197',
#  'A4': 'F30658',
#  'A5': 'F5677',
#  'A6': 'M37351',
#  'A7': 'S86968',
#  'A8': 'T36994',
#  'A9': 'W36662',
#  'A10': 'W60856',
#  'A11': 'UCBPP-PA14',
#  'A12': 'Water',
#  'B1': 'Blank',
#  'B2': 'F20590',
#  'B3': 'F23197',
#  'B4': 'F30658',
#  'B5': 'F5677',
#  'B6': 'M37351',
#  'B7': 'S86968',
#  'B8': 'T36994',
#  'B9': 'W36662',
#  'B10': 'W60856',
#  'B11': 'UCBPP-PA14',
#  'B12': 'Water',
#  'C1': 'Blank',
#  'C2': 'F20590',
#  'C3': 'F23197',
#  'C4': 'F30658',
#  'C5': 'F5677',
#  'C6': 'M37351',
#  'C7': 'S86968',
#  'C8': 'T36994',
#  'C9': 'W36662',
#  'C10': 'W60856',
#  'C11': 'UCBPP-PA14',
#  'C12': 'Water',
#  'D1': 'Blank',
#  'D2': 'F20590',
#  'D3': 'F23197',
#  'D4': 'F30658',
#  'D5': 'F5677',
#  'D6': 'M37351',
#  'D7': 'S86968',
#  'D8': 'T36994',
#  'D9': 'W36662',
#  'D10': 'W60856',
#  'D11': 'UCBPP-PA14',
#  'D12': 'Water',
#  'E1': 'Blank',
#  'E2': 'F20590',
#  'E3': 'F23197',
# ...

# %%
# %run growth_curve_analysis.py

df2write_012120GlycerolGrowthCurve_Spark = growth_curve_analysis_chenL(
    '../data/012120GlycerolGrowthCurve_Spark.xlsx',
    blank=['12'],
    #which_curves=['E3','G3'],
    OD_cutoff=0.0,
    verbose=0,
    is_plot=True,
    # plot_dim=[2,1],
    # xlim=[18,30],
    # ylim=[0.0,1],
    fitting_method_in_plot=['exp'],
    is_write=True,
    R2_logscale=False,
    well_name_dict=well_name_dict_0121_Spark
)
# Out:
# /usr/local/lib/python3.7/site-packages/scipy/optimize/minpack.py:808: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /usr/local/lib/python3.7/site-packages/croissance/estimation/regression.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   return numpy.var(fit) / numpy.var(series.values - fit)

# %%
df2write_012120GlycerolGrowthCurve_Spark.head()
# Out:
#    curve well  phase  start_time  end_time  growth_rate_EXP  \
# 0  Blank   A1    NaN         NaN       NaN              NaN
# 1  Blank   B1    NaN         NaN       NaN              NaN
# 2  Blank   C1    NaN         NaN       NaN              NaN
# 3  Blank   D1    NaN         NaN       NaN              NaN
# 4  Blank   E1    NaN         NaN       NaN              NaN
#
#    growth_ratt_std_exp  R2_EXP  std_EXP_wOS  growth_rate_EXP_wOS  R2_EXP_wOS  \
# 0                  NaN     NaN          NaN                  NaN         NaN
# 1                  NaN     NaN          NaN                  NaN         NaN
# 2                  NaN     NaN          NaN                  NaN         NaN
# 3                  NaN     NaN          NaN                  NaN         NaN
# 4                  NaN     NaN          NaN                  NaN         NaN
#
#    growth_rate_ZG  R2_ZG  growth_rate_ZL  R2_ZL  std_EXP
# 0             NaN    NaN             NaN    NaN      NaN
# ...

# %% [markdown]
# # 012120GlycerolGrowthCurve_Hildi

# %%
column_strains_0121_Hildi = ['Blank','W91453','X78812','UCBPP-PA14','Water']
well_name_dict_0121_Hildi = {}
for row in string.ascii_uppercase[:8]:
    for col in range(1,6):
        well_name_dict_0121_Hildi[row+str(col)] = column_strains_0121_Hildi[col-1]
well_name_dict_0121_Hildi
# Out:
# {'A1': 'Blank',
#  'A2': 'W91453',
#  'A3': 'X78812',
#  'A4': 'UCBPP-PA14',
#  'A5': 'Water',
#  'B1': 'Blank',
#  'B2': 'W91453',
#  'B3': 'X78812',
#  'B4': 'UCBPP-PA14',
#  'B5': 'Water',
#  'C1': 'Blank',
#  'C2': 'W91453',
#  'C3': 'X78812',
#  'C4': 'UCBPP-PA14',
#  'C5': 'Water',
#  'D1': 'Blank',
#  'D2': 'W91453',
#  'D3': 'X78812',
#  'D4': 'UCBPP-PA14',
#  'D5': 'Water',
#  'E1': 'Blank',
#  'E2': 'W91453',
#  'E3': 'X78812',
#  'E4': 'UCBPP-PA14',
#  'E5': 'Water',
#  'F1': 'Blank',
#  'F2': 'W91453',
#  'F3': 'X78812',
#  'F4': 'UCBPP-PA14',
#  'F5': 'Water',
#  'G1': 'Blank',
#  'G2': 'W91453',
#  'G3': 'X78812',
#  'G4': 'UCBPP-PA14',
#  'G5': 'Water',
#  'H1': 'Blank',
#  'H2': 'W91453',
#  'H3': 'X78812',
#  'H4': 'UCBPP-PA14',
#  'H5': 'Water'}

# %%
# %run growth_curve_analysis.py

df2write_012120GlycerolGrowthCurve_Hildi = growth_curve_analysis_chenL(
    '../data/012120GlycerolGrowthCurve_Hildi.xlsx',
    blank=['5'],
    #which_curves=['E3','G3'],
    OD_cutoff=0.0,
    verbose=0,
    is_plot=True,
    # plot_dim=[2,1],
    # xlim=[18,30],
    # ylim=[0.0,1],
    fitting_method_in_plot=['exp'],
    is_write=True,
    R2_logscale=False,
    well_name_dict=well_name_dict_0121_Hildi
)
# Out:
# /usr/local/lib/python3.7/site-packages/scipy/optimize/minpack.py:808: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /usr/local/lib/python3.7/site-packages/croissance/estimation/regression.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   return numpy.var(fit) / numpy.var(series.values - fit)

# %%
df2write_012120GlycerolGrowthCurve_Hildi.head()
# Out:
#    curve well  phase  start_time  end_time  growth_rate_EXP  \
# 0  Blank   A1    NaN         NaN       NaN              NaN
# 1  Blank   B1    NaN         NaN       NaN              NaN
# 2  Blank   C1    NaN         NaN       NaN              NaN
# 3  Blank   D1    NaN         NaN       NaN              NaN
# 4  Blank   E1    NaN         NaN       NaN              NaN
#
#    growth_ratt_std_exp  R2_EXP  std_EXP_wOS  growth_rate_EXP_wOS  R2_EXP_wOS  \
# 0                  NaN     NaN          NaN                  NaN         NaN
# 1                  NaN     NaN          NaN                  NaN         NaN
# 2                  NaN     NaN          NaN                  NaN         NaN
# 3                  NaN     NaN          NaN                  NaN         NaN
# 4                  NaN     NaN          NaN                  NaN         NaN
#
#    growth_rate_ZG  R2_ZG  growth_rate_ZL  R2_ZL  std_EXP
# 0             NaN    NaN             NaN    NaN      NaN
# ...

# %% [markdown]
# # 030420GlycerolGrowthCurve_Hildi

# %%
column_strains_0304_Hildi = ['Blank','UCBPP-PA14','PAO1','PA7','Water']
well_name_dict_0304_Hildi = {}
for row in string.ascii_uppercase[:8]:
    for col in range(1,6):
        well_name_dict_0304_Hildi[row+str(col)] = column_strains_0304_Hildi[col-1]
well_name_dict_0304_Hildi
# Out:
# {'A1': 'Blank',
#  'A2': 'UCBPP-PA14',
#  'A3': 'PAO1',
#  'A4': 'PA7',
#  'A5': 'Water',
#  'B1': 'Blank',
#  'B2': 'UCBPP-PA14',
#  'B3': 'PAO1',
#  'B4': 'PA7',
#  'B5': 'Water',
#  'C1': 'Blank',
#  'C2': 'UCBPP-PA14',
#  'C3': 'PAO1',
#  'C4': 'PA7',
#  'C5': 'Water',
#  'D1': 'Blank',
#  'D2': 'UCBPP-PA14',
#  'D3': 'PAO1',
#  'D4': 'PA7',
#  'D5': 'Water',
#  'E1': 'Blank',
#  'E2': 'UCBPP-PA14',
#  'E3': 'PAO1',
#  'E4': 'PA7',
#  'E5': 'Water',
#  'F1': 'Blank',
#  'F2': 'UCBPP-PA14',
#  'F3': 'PAO1',
#  'F4': 'PA7',
#  'F5': 'Water',
#  'G1': 'Blank',
#  'G2': 'UCBPP-PA14',
#  'G3': 'PAO1',
#  'G4': 'PA7',
#  'G5': 'Water',
#  'H1': 'Blank',
#  'H2': 'UCBPP-PA14',
#  'H3': 'PAO1',
#  'H4': 'PA7',
#  'H5': 'Water'}

# %%
# %run growth_curve_analysis.py

df2write_030420GlycerolGrowthCurve_Hildi = growth_curve_analysis_chenL(
    '../data/030420GlycerolGrowthCurve_Hildi.xlsx',
    blank=['5'],
    #which_curves=['E3','G3'],
    OD_cutoff=0.0,
    verbose=0,
    is_plot=True,
    # plot_dim=[2,1],
    # xlim=[18,30],
    # ylim=[0.0,1],
    fitting_method_in_plot=['exp'],
    is_write=True,
    R2_logscale=False,
    well_name_dict=well_name_dict_0304_Hildi
)
# Out:
# /usr/local/lib/python3.7/site-packages/croissance/estimation/regression.py:45: RuntimeWarning: divide by zero encountered in double_scalars
#   intercept = - c / slope
# /usr/local/lib/python3.7/site-packages/croissance/estimation/regression.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   return numpy.var(fit) / numpy.var(series.values - fit)

# %%
df2write_030420GlycerolGrowthCurve_Hildi.head()
# Out:
#    curve well  phase  start_time   end_time  growth_rate_EXP   std_EXP  \
# 0  Blank   A1    1.0   32.100556  33.959000         0.530728  0.118482
# 1  Blank   B1    NaN         NaN        NaN              NaN       NaN
# 2  Blank   C1    1.0   39.534361  43.758139         0.159923  0.032225
# 3  Blank   D1    NaN         NaN        NaN              NaN       NaN
# 4  Blank   E1    NaN         NaN        NaN              NaN       NaN
#
#      R2_EXP  growth_rate_EXP_wOS  std_EXP_wOS  R2_EXP_wOS  growth_rate_ZG  \
# 0  0.696869             0.530728     0.887989    0.696869       19.380699
# 1       NaN                  NaN          NaN         NaN             NaN
# 2  0.516687             0.363937     0.376728    0.518784        0.166835
# 3       NaN                  NaN          NaN         NaN             NaN
# 4       NaN                  NaN          NaN         NaN             NaN
#
#       R2_ZG  growth_rate_ZL     R2_ZL  growth_ratt_std_exp
# ...

# %% [markdown]
# # 181109_glycerol_clinical

# %%
column_strains_181109 = ['Blank','UCBPP-PA14','W25637','W36662','M1608','W91453','F22031','F9670','M37351','T38079','X9820','Water']
well_name_dict_181109 = {}
for row in string.ascii_uppercase[:8]:
    for col in range(1,13):
        well_name_dict_181109[row+str(col)] = column_strains_181109[col-1]
well_name_dict_181109
# Out:
# {'A1': 'Blank',
#  'A2': 'UCBPP-PA14',
#  'A3': 'W25637',
#  'A4': 'W36662',
#  'A5': 'M1608',
#  'A6': 'W91453',
#  'A7': 'F22031',
#  'A8': 'F9670',
#  'A9': 'M37351',
#  'A10': 'T38079',
#  'A11': 'X9820',
#  'A12': 'Water',
#  'B1': 'Blank',
#  'B2': 'UCBPP-PA14',
#  'B3': 'W25637',
#  'B4': 'W36662',
#  'B5': 'M1608',
#  'B6': 'W91453',
#  'B7': 'F22031',
#  'B8': 'F9670',
#  'B9': 'M37351',
#  'B10': 'T38079',
#  'B11': 'X9820',
#  'B12': 'Water',
#  'C1': 'Blank',
#  'C2': 'UCBPP-PA14',
#  'C3': 'W25637',
#  'C4': 'W36662',
#  'C5': 'M1608',
#  'C6': 'W91453',
#  'C7': 'F22031',
#  'C8': 'F9670',
#  'C9': 'M37351',
#  'C10': 'T38079',
#  'C11': 'X9820',
#  'C12': 'Water',
#  'D1': 'Blank',
#  'D2': 'UCBPP-PA14',
#  'D3': 'W25637',
#  'D4': 'W36662',
#  'D5': 'M1608',
#  'D6': 'W91453',
#  'D7': 'F22031',
#  'D8': 'F9670',
#  'D9': 'M37351',
#  'D10': 'T38079',
#  'D11': 'X9820',
#  'D12': 'Water',
#  'E1': 'Blank',
#  'E2': 'UCBPP-PA14',
#  'E3': 'W25637',
#  'E4': 'W36662',
# ...

# %%
# %run growth_curve_analysis.py

df2write_181109_glycerol_clinical = growth_curve_analysis_chenL(
    '../data/181109_glycerol_clinical.xlsx',
    blank=['12'],
    #which_curves=['E3','G3'],
    OD_cutoff=0.0,
    verbose=0,
    is_plot=True,
    # plot_dim=[2,1],
    # xlim=[18,30],
    # ylim=[0.0,1],
    fitting_method_in_plot=['exp'],
    is_write=True,
    R2_logscale=False,
    well_name_dict=well_name_dict_181109
)
# Out:
# /Users/liaoc/GoogleDrive/Guillem_metabolomics_paper/growth_curve_analysis_fit_w_Croissance_2nd_derive_negative/growth_curve_analysis.py:20: RuntimeWarning: overflow encountered in exp
#   return y0 + A*np.exp(-np.exp(mu*np.exp(1)/A*(lag-x)+1))

# %%
df2write_181109_glycerol_clinical.head()
# Out:
#    curve well  phase  start_time  end_time  growth_rate_EXP  \
# 0  Blank   A1    NaN         NaN       NaN              NaN
# 1  Blank   B1    1.0    3.725694  5.757889         0.670873
# 2  Blank   C1    NaN         NaN       NaN              NaN
# 3  Blank   D1    NaN         NaN       NaN              NaN
# 4  Blank   E1    NaN         NaN       NaN              NaN
#
#    growth_ratt_std_exp    R2_EXP  std_EXP_wOS  growth_rate_EXP_wOS  \
# 0                  NaN       NaN          NaN                  NaN
# 1                  NaN  0.772472     0.645893             1.617575
# 2                  NaN       NaN          NaN                  NaN
# 3                  NaN       NaN          NaN                  NaN
# 4                  NaN       NaN          NaN                  NaN
#
#    R2_EXP_wOS  growth_rate_ZG     R2_ZG  growth_rate_ZL     R2_ZL  std_EXP
# 0         NaN             NaN       NaN             NaN       NaN      NaN
# ...
